# %% [markdown]
# # Unit 1: Applying the Numerical Derivative
#
# In the last notebook, you built a powerful tool: a Python function that can calculate the instantaneous rate of change (the derivative) for any mathematical function.
#
# Now, it is your turn to write the code. In this notebook, you will use your numerical derivative to solve classic calculus problems without doing any algebraic manipulation by hand.
#
# First, let's bring in our tools and redefine the function we built in the last lesson.

# %%
import numpy as np
import matplotlib.pyplot as plt

def numerical_derivative(f, x, h=1e-5):
    return (f(x + h) - f(x)) / h

# %% [markdown]
# ## Challenge 1: The Tangent Line Equation
#
# **The Problem:**
# Given the function $f(x) = x^3 - 4x^2 + x + 6$, find the equation of the tangent line at $x = 3$. Then, plot both the original function and your tangent line on the same graph to verify your answer visually.
#
# **Your Task:**
#
# 1. Define the function $f(x)$ in Python.
# 2. Use `numerical_derivative` to find the slope $m$ at $x = 3$.
# 3. Find the y-coordinate at $x = 3$.
# 4. Create a new function for the tangent line using point-slope form: $y = m(x - x_1) + y_1$.
# 5. Graph them both!

# %%
# Write your code for Challenge 1 here!

# %% [markdown]
# ## Challenge 2: Finding Peaks and Valleys (Extrema)
#
# **The Problem:**
# In calculus, we often want to find the maximum or minimum values of a function. We know that at a peak or a valley, the tangent line is perfectly flat. This means the slope (the derivative) is exactly $0$.
#
# Let's look at the function $g(x) = \sin(x) + \cos(x)$ on the interval $0$ to $2\pi$.
#
# **Your Task:**
#
# 1. Define $g(x)$.
# 2. Calculate the derivative of $g(x)$ across an array of 1000 points between $0$ and $2\pi$.
# 3. Plot the derivative. Look at where the derivative crosses the x-axis (where $y = 0$).
# 4. Write a script that loops through your derivative array and prints the approximate $x$-values where the derivative is closest to zero. *(Hint: Look for where the derivative changes from positive to negative!)*

# %%
# Write your code for Challenge 2 here!

# %% [markdown]
# ## Challenge 3: Physics and Kinematics
#
# **The Problem:**
# Derivatives are the foundation of physics. If you have a function that represents the **position** of an object over time, the derivative of that function represents its **velocity**.
#
# A model rocket is launched upward. Its height in meters over time in seconds is given by the function:
#
#
# $$h(t) = -4.9t^2 + 50t + 2$$
#
# **Your Task:**
#
# 1. Define the position function $h(t)$.
# 2. Create an array of time values from $t=0$ to $t=10$.
# 3. Compute the velocity of the rocket at each time step using your numerical derivative.
# 4. Plot the velocity over time.
# 5. Based on your velocity data, at what approximate time does the rocket stop going up and start falling back down? Print that time.

# %%
# Write your code for Challenge 3 here!
